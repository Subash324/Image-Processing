# %%
import numpy as np

# %%
# !pip install -q -U opencv-python

# %%
# !pip uninstall imgaug
# Out:
# Found existing installation: imgaug 0.2.9
# Uninstalling imgaug-0.2.9:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/imgaug-0.2.9.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/imgaug/*
# Proceed (y/n)? y
#   Successfully uninstalled imgaug-0.2.9

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img =cv2.imread("/content/drive/MyDrive/5th sem/image processing/photos/Copy of messi.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=496x312 at 0x7F7A6FB00CD0>

# %%
grayImage = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow( grayImage)
# Out:
# <PIL.Image.Image image mode=L size=496x312 at 0x7F7A5D94FB10>

# %%
cv2_imshow(255 - grayImage)
# Out:
# <PIL.Image.Image image mode=L size=496x312 at 0x7F7A5D9581D0>

# %%
 (thresh, blackAndWhiteImage) = cv2.threshold(grayImage, 127, 255, cv2.THRESH_BINARY)

# %%
cv2_imshow(blackAndWhiteImage)
# Out:
# <PIL.Image.Image image mode=L size=496x312 at 0x7F7A5D965DD0>

# %%
image_edge=cv2.Canny(img,0,100)

# %%
cv2_imshow(image_edge)
# Out:
# <PIL.Image.Image image mode=L size=496x312 at 0x7F7A5D94F390>

# %%
image_edge.shape
# Out:
# (312, 496)

# %%
retval, threshold = cv2.threshold(img,15,255,cv2.THRESH_BINARY)
cv2_imshow(threshold)
# Out:
# <PIL.Image.Image image mode=RGB size=496x312 at 0x7F7A5D965610>

# %%
grayscaled = cv2.cvtColor(threshold, cv2.COLOR_BGR2GRAY)
retval, threshold = cv2.threshold(grayscaled,15,255,cv2.THRESH_BINARY)
cv2_imshow(grayscaled)
cv2_imshow(threshold)
# Out:
# <PIL.Image.Image image mode=L size=496x312 at 0x7F7A5C0F9590>
# <PIL.Image.Image image mode=L size=496x312 at 0x7F7A5C0F9C10>
